# %% [markdown]
# ### To take the clean data (train) and separate it by Students/Workers.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Mental_Health = pd.read_csv('Datasheet/MH.wCity.Clean.2.5.csv')

# %%
Mental_Health['Financial Stress']=Mental_Health['Financial Stress'].fillna(Mental_Health['Financial Stress'].mean())

# %%
Mental_Health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140700 entries, 0 to 140699
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     140700 non-null  int64
#  1   Gender                                 140700 non-null  int64
#  2   Age                                    140700 non-null  float64
#  3   City                                   140700 non-null  object
#  4   CGPA                                   27898 non-null   float64
#  5   Sleep Duration                         140700 non-null  float64
#  6   Dietary Habits                         140700 non-null  float64
#  7   Have you ever had suicidal thoughts ?  140700 non-null  int64
#  8   Work/Study Hours                       140700 non-null  float64
#  9   Financial Stress                       140700 non-null  float64
# ...

# %%
Mental_Health
# Out:
#             id  Gender   Age           City  CGPA  Sleep Duration  \
# 0            0       1  49.0       Ludhiana   NaN             8.5
# 1            1       0  26.0       Varanasi   NaN             4.5
# 2            2       0  33.0  Visakhapatnam  8.97             5.5
# 3            3       0  22.0         Mumbai   NaN             4.5
# 4            4       1  30.0         Kanpur   NaN             5.5
# ...        ...     ...   ...            ...   ...             ...
# 140695  140695       1  18.0      Ahmedabad   NaN             5.5
# 140696  140696       1  41.0      Hyderabad   NaN             7.5
# 140697  140697       1  24.0        Kolkata   NaN             8.5
# 140698  140698       1  49.0       Srinagar   NaN             5.5
# 140699  140699       0  27.0          Patna  9.24             4.5
#
#         Dietary Habits  Have you ever had suicidal thoughts ?  \
# 0                  2.0                                      0
# ...

# %% [markdown]
# ### I will make a data frame by Students/workers

# %%
Mental_Health['Work'].unique()
# Out:
# array(['Working Professional', 'Student'], dtype=object)

# %%
for worker in Mental_Health['Work'].unique():
    worker_df = Mental_Health[Mental_Health['Work'] == worker]
    worker_df.to_csv(f'Datasheet/MH.{worker}.Clean.2.5.csv', index=False)
