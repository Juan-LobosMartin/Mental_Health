# %% [markdown]
# ### To take the clean data (train) and separate it by cities.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Mental_Health = pd.read_csv('Datasheet/MH.wCity.Clean.2b.csv')

# %%
Mental_Health['Financial Stress']=Mental_Health['Financial Stress'].fillna(Mental_Health['Financial Stress'].mean())

# %%
Mental_Health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140700 entries, 0 to 140699
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     140700 non-null  int64
#  1   Gender                                 140700 non-null  int64
#  2   Age                                    140700 non-null  float64
#  3   City                                   140700 non-null  object
#  4   Sleep Duration                         140700 non-null  float64
#  5   Dietary Habits                         140700 non-null  float64
#  6   Have you ever had suicidal thoughts ?  140700 non-null  int64
#  7   Work/Study Hours                       140700 non-null  float64
#  8   Financial Stress                       140700 non-null  float64
#  9   Family History of Mental Illness       140700 non-null  int64
#  10  Work                                   140700 non-null  object
#  11  Satisfaction                           140700 non-null  float64
#  12  Pressure                               140700 non-null  float64
#  13  Depression                             140700 non-null  int64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 15.0+ MB

# %%
Mental_Health
# Out:
#             id  Gender   Age           City  Sleep Duration  Dietary Habits  \
# 0            0       1  49.0       Ludhiana             8.5             2.0
# 1            1       0  26.0       Varanasi             4.5             0.0
# 2            2       0  33.0  Visakhapatnam             5.5             2.0
# 3            3       0  22.0         Mumbai             4.5             1.0
# 4            4       1  30.0         Kanpur             5.5             0.0
# ...        ...     ...   ...            ...             ...             ...
# 140695  140695       1  18.0      Ahmedabad             5.5             0.0
# 140696  140696       1  41.0      Hyderabad             7.5             1.0
# 140697  140697       1  24.0        Kolkata             8.5             1.0
# 140698  140698       1  49.0       Srinagar             5.5             1.0
# 140699  140699       0  27.0          Patna             4.5             2.0
#
#         Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                           0               1.0
# 1                                           1               7.0
# 2                                           1               3.0
# 3                                           1              10.0
# 4                                           1               9.0
# ...                                       ...               ...
# 140695                                      0               2.0
# 140696                                      1               6.0
# 140697                                      0               4.0
# 140698                                      1              10.0
# 140699                                      1               2.0
#
#         Financial Stress  Family History of Mental Illness  \
# 0                    2.0                                 0
# 1                    3.0                                 0
# 2                    1.0                                 0
# 3                    1.0                                 1
# 4                    4.0                                 1
# ...                  ...                               ...
# 140695               4.0                                 1
# 140696               5.0                                 1
# 140697               4.0                                 0
# 140698               1.0                                 0
# 140699               3.0                                 1
#
#                         Work  Satisfaction  Pressure  Depression
# 0       Working Professional           2.0       5.0           0
# 1       Working Professional           3.0       4.0           1
# 2                    Student           2.0       5.0           1
# 3       Working Professional           1.0       5.0           1
# 4       Working Professional           1.0       1.0           0
# ...                      ...           ...       ...         ...
# 140695  Working Professional           4.0       5.0           1
# 140696  Working Professional           4.0       5.0           0
# 140697  Working Professional           1.0       3.0           0
# 140698  Working Professional           2.0       5.0           0
# 140699               Student           1.0       4.0           1
#
# [140700 rows x 14 columns]

# %% [markdown]
# ### I will make a data frame by Students/workers

# %%
Mental_Health['Work'].unique()
# Out:
# array(['Working Professional', 'Student'], dtype=object)

# %%
for worker in Mental_Health['Work'].unique():
    worker_df = Mental_Health[Mental_Health['Work'] == worker]
    worker_df.to_csv(f'Datasheet/MH.{worker}.Clean.2b.csv', index=False)
