# %% [markdown]
# # Model RandomForestRegressor
#
# - Several columns were dropped
# - Simple optimized model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Mental_1 = pd.read_csv('Datasheet/MH.Clean.1.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.preprocessing import scale
import sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %% [markdown]
# ### Data for train the model

# %%
X = Mental_1.drop(columns=['id', 'Depression'],axis=1)
y = Mental_1['Depression']

# %%
# check the param of the model
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# modification of the param
params = {'ccp_alpha': [0.01 ,0.05, 0.1],
 'max_depth': [3, 4, 5, 6], # branches of the trees
 'max_features': [0.1, 0.3, 0.6, 0.8], # features considered
 'max_samples': [0.4, 0.6,0.8], # test-train population
 'n_estimators': [1000], # number trees
 'n_jobs': [-1]} # multicore

# %%
n_cv = 5
model = RandomForestRegressor()

scoring = ['neg_mean_squared_error', 'explained_variance', 'r2']

# I made the evaluation with GridSeacrh
grid_solver = GridSearchCV(estimator = model, # model to train
                           param_grid = params, # param_grid
                           scoring = scoring,
                           cv = n_cv, #number of independent 
                           refit = 'neg_mean_squared_error',
                           verbose = 2)

# %%
# searchin for the trees in the forest.
model_result = grid_solver.fit(X, y)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   4.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   5.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   5.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   5.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.05, max_depth=3, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.05, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.05, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# ...
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.1, max_depth=4, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.6s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   4.2s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.9s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   5.2s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.8s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.5s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.5s
# [CV] END ccp_alpha=0.1, max_depth=6, max_features=0.8, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   4.5s

# %%
model_result.best_estimator_
# Out:
# RandomForestRegressor(ccp_alpha=0.01, max_depth=5, max_features=0.6,
#                       max_samples=0.6, n_estimators=1000, n_jobs=-1)

# %%
results = model_result.cv_results_
results = pd.DataFrame(results)

# %%
results[['mean_test_neg_mean_squared_error','params','param_max_depth','param_max_samples']]
# Out:
#      mean_test_neg_mean_squared_error  \
# 0                           -0.112614
# 1                           -0.111717
# 2                           -0.112479
# 3                           -0.088056
# 4                           -0.087804
# ..                                ...
# 139                         -0.148694
# 140                         -0.148694
# 141                         -0.148694
# 142                         -0.148694
# 143                         -0.148694
#
#                                                 params param_max_depth  \
# 0    {'ccp_alpha': 0.01, 'max_depth': 3, 'max_featu...               3
# 1    {'ccp_alpha': 0.01, 'max_depth': 3, 'max_featu...               3
# 2    {'ccp_alpha': 0.01, 'max_depth': 3, 'max_featu...               3
# 3    {'ccp_alpha': 0.01, 'max_depth': 3, 'max_featu...               3
# 4    {'ccp_alpha': 0.01, 'max_depth': 3, 'max_featu...               3
# ..                                                 ...             ...
# 139  {'ccp_alpha': 0.1, 'max_depth': 6, 'max_featur...               6
# 140  {'ccp_alpha': 0.1, 'max_depth': 6, 'max_featur...               6
# 141  {'ccp_alpha': 0.1, 'max_depth': 6, 'max_featur...               6
# 142  {'ccp_alpha': 0.1, 'max_depth': 6, 'max_featur...               6
# 143  {'ccp_alpha': 0.1, 'max_depth': 6, 'max_featur...               6
#
#     param_max_samples
# 0                 0.4
# 1                 0.6
# 2                 0.8
# 3                 0.4
# 4                 0.6
# ..                ...
# 139               0.6
# 140               0.8
# 141               0.4
# 142               0.6
# 143               0.8
#
# [144 rows x 4 columns]

# %%
sns.relplot(x = "param_max_depth", 
            y = "mean_test_neg_mean_squared_error", # error in y axis
            style="param_max_samples", # max number % of rows by tree
            hue="param_ccp_alpha",
            col="param_max_features",
            kind = "line", data=results)

# %%
dep_resoult = model_result.best_estimator_

# %%
y_pred_V1 = dep_resoult.predict(X)
y_pred_V1
# Out:
# array([0.00428012, 0.84198939, 0.55000783, ..., 0.26938298, 0.06868556,
#        0.76005572])

# %%
threshold = 0.5
y_pred_V1_bin = np.where(y_pred_V1 > threshold, 1, 0)
y_pred_V1_bin
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
from sklearn.metrics import confusion_matrix

def confusion(ytest,y_pred):
    names=["No depresive","Depressive"]
    cm=confusion_matrix(y,y_pred_V1_bin)
    f,ax=plt.subplots(figsize=(5,5))
    sns.heatmap(cm,annot=True,linewidth=.5,linecolor="r",fmt=".0f",ax=ax)
    plt.xlabel("y_pred")
    plt.ylabel("y_true")
    ax.set_xticklabels(names)
    ax.set_yticklabels(names)
    plt.show()

    return

# %%
confusion(y,y_pred_V1_bin)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y,y_pred_V1_bin)
# Out:
# 0.9257924662402275

# %% [markdown]
# The cross-validation was done by 5 with more parameters than the other forest, but only slightly better accuracy by 200 persons in 140700.

# %%
grid_solver.best_estimator_
# Out:
# RandomForestRegressor(max_depth=6, max_features=0.6, max_samples=0.4,
#                       n_estimators=1000, n_jobs=-1)

# %% [markdown]
# # apply the best estimator to Test dataframe

# %%
Mental_1 = pd.read_csv('Datasheet/MH.Clean.Test.1.csv')

# %%
Mental_1.drop(columns=['id'],axis=1)
# Out:
#        Gender   Age  Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0           0  53.0                                      0               9.0
# 1           1  58.0                                      0               6.0
# 2           0  53.0                                      1              12.0
# 3           1  23.0                                      1              10.0
# 4           0  47.0                                      1               3.0
# ...       ...   ...                                    ...               ...
# 93795       1  49.0                                      1               2.0
# 93796       0  29.0                                      1              11.0
# 93797       0  24.0                                      0               7.0
# 93798       1  23.0                                      1               7.0
# 93799       1  43.0                                      0              11.0
#
#        Financial Stress  Family History of Mental Illness  Pressure  \
# 0                   3.0                                 1       2.0
# 1                   4.0                                 0       2.0
# 2                   4.0                                 0       4.0
# 3                   4.0                                 0       5.0
# 4                   4.0                                 0       5.0
# ...                 ...                               ...       ...
# 93795               2.0                                 1       3.0
# 93796               3.0                                 1       5.0
# 93797               1.0                                 0       1.0
# 93798               5.0                                 1       4.0
# 93799               2.0                                 0       5.0
#
#        Satisfaction
# 0               5.0
# 1               4.0
# 2               1.0
# 3               1.0
# 4               5.0
# ...             ...
# 93795           5.0
# 93796           1.0
# 93797           4.0
# 93798           2.0
# 93799           2.0
#
# [93800 rows x 8 columns]

# %%
modelo_MH = model_result.best_estimator_

# %%
modelo_MH
# Out:
# RandomForestRegressor(max_depth=6, max_features=0.6, max_samples=0.4,
#                       n_estimators=1000, n_jobs=-1)

# %%
y_pre = modelo_MH.predict(Mental_1.drop(columns=['id'],axis=1))

# %%
y_pre
# Out:
# array([0.00162874, 0.00156994, 0.06148592, ..., 0.05113231, 0.91394167,
#        0.01235383])

# %%
# define a threshold
threshold = 0.5
y_pre_bin = np.where(y_pre > threshold, 1, 0)

# %%
y_pre_bin
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
Mental_1['Depression']= y_pre_bin

# %%
Mental_1
# Out:
#            id  Gender   Age  Have you ever had suicidal thoughts ?  \
# 0      140700       0  53.0                                      0
# 1      140701       1  58.0                                      0
# 2      140702       0  53.0                                      1
# 3      140703       1  23.0                                      1
# 4      140704       0  47.0                                      1
# ...       ...     ...   ...                                    ...
# 93795  234495       1  49.0                                      1
# 93796  234496       0  29.0                                      1
# 93797  234497       0  24.0                                      0
# 93798  234498       1  23.0                                      1
# 93799  234499       1  43.0                                      0
#
#        Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0                   9.0               3.0                                 1
# 1                   6.0               4.0                                 0
# 2                  12.0               4.0                                 0
# 3                  10.0               4.0                                 0
# 4                   3.0               4.0                                 0
# ...                 ...               ...                               ...
# 93795               2.0               2.0                                 1
# 93796              11.0               3.0                                 1
# 93797               7.0               1.0                                 0
# 93798               7.0               5.0                                 1
# 93799              11.0               2.0                                 0
#
#        Pressure  Satisfaction  Depression
# 0           2.0           5.0           0
# 1           2.0           4.0           0
# 2           4.0           1.0           0
# 3           5.0           1.0           1
# 4           5.0           5.0           0
# ...         ...           ...         ...
# 93795       3.0           5.0           0
# 93796       5.0           1.0           1
# 93797       1.0           4.0           0
# 93798       4.0           2.0           1
# 93799       5.0           2.0           0
#
# [93800 rows x 10 columns]

# %%
Mental_1['Depression'].value_counts()
# Out:
# Depression
# 0    77251
# 1    16549
# Name: count, dtype: int64

# %%
print(Mental_1.keys())
# Out:
# Index(['id', 'Gender', 'Age', 'Have you ever had suicidal thoughts ?',
#        'Work/Study Hours', 'Financial Stress',
#        'Family History of Mental Illness', 'Pressure', 'Satisfaction',
#        'Depression'],
#       dtype='object')

# %%
sample_submission = Mental_1.drop(columns=['Gender', 'Age', 'Have you ever had suicidal thoughts ?',
       'Work/Study Hours', 'Financial Stress','Family History of Mental Illness', 'Pressure', 'Satisfaction'],axis=1)

# %%
sample_submission
# Out:
#            id  Depression
# 0      140700           0
# 1      140701           0
# 2      140702           0
# 3      140703           1
# 4      140704           0
# ...       ...         ...
# 93795  234495           0
# 93796  234496           1
# 93797  234497           0
# 93798  234498           1
# 93799  234499           0
#
# [93800 rows x 2 columns]

# %%
sample_submission.to_csv('sample_submission_1.csv', index=False)
