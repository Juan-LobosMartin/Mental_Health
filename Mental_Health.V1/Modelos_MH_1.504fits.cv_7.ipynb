# %% [markdown]
# # Model RandomForestRegressor
#
# - Several columns were dropped
# - Simple optimized model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Mental_1 = pd.read_csv('Datasheet/MH.Clean.1.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.preprocessing import scale
import sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %% [markdown]
# ### Data for train the model

# %%
X = Mental_1.drop(columns=['id', 'Depression'],axis=1)
y = Mental_1['Depression']

# %%
# check the param of the model
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# modification of the param
params = {'ccp_alpha': [0.0 ,0.01],
 'max_depth': [3, 4, 5, 6], # branches of the trees
 'max_features': [0.1, 0.3, 0.6], # features considered
 'max_samples': [0.4, 0.6,0.8], # test-train population
 'n_estimators': [1000], # number trees
 'n_jobs': [-1]} # multicore

# %%
n_cv = 7
model = RandomForestRegressor()

scoring = ['neg_mean_squared_error', 'explained_variance', 'r2']

# I made the evaluation with GridSeacrh
grid_solver = GridSearchCV(estimator = model, # model to train
                           param_grid = params, # param_grid
                           scoring = scoring,
                           cv = n_cv, #number of independent 
                           refit = 'neg_mean_squared_error',
                           verbose = 2)

# %%
# searchin for the trees in the forest.
model_result = grid_solver.fit(X, y)
# Out:
# Fitting 7 folds for each of 72 candidates, totalling 504 fits
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.0, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.6s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.0, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.2s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=3, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=4, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.6s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.8s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.6s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   1.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.2s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.1, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   1.8s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.3, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   2.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   2.3s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.2s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   2.9s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.4s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.6s
# [CV] END ccp_alpha=0.01, max_depth=6, max_features=0.6, max_samples=0.8, n_estimators=1000, n_jobs=-1; total time=   3.7s

# %%
model_result.best_estimator_
# Out:
# RandomForestRegressor(max_depth=6, max_features=0.6, max_samples=0.4,
#                       n_estimators=1000, n_jobs=-1)

# %%
results = model_result.cv_results_
results = pd.DataFrame(results)

# %%
results[['mean_test_neg_mean_squared_error','params','param_max_depth','param_max_samples']]
# Out:
#     mean_test_neg_mean_squared_error  \
# 0                          -0.094365
# 1                          -0.094888
# 2                          -0.095220
# 3                          -0.075522
# 4                          -0.075335
# ..                               ...
# 67                         -0.085860
# 68                         -0.085556
# 69                         -0.068385
# 70                         -0.068308
# 71                         -0.068293
#
#                                                params param_max_depth  \
# 0   {'ccp_alpha': 0.0, 'max_depth': 3, 'max_featur...               3
# 1   {'ccp_alpha': 0.0, 'max_depth': 3, 'max_featur...               3
# 2   {'ccp_alpha': 0.0, 'max_depth': 3, 'max_featur...               3
# 3   {'ccp_alpha': 0.0, 'max_depth': 3, 'max_featur...               3
# 4   {'ccp_alpha': 0.0, 'max_depth': 3, 'max_featur...               3
# ..                                                ...             ...
# 67  {'ccp_alpha': 0.01, 'max_depth': 6, 'max_featu...               6
# 68  {'ccp_alpha': 0.01, 'max_depth': 6, 'max_featu...               6
# 69  {'ccp_alpha': 0.01, 'max_depth': 6, 'max_featu...               6
# 70  {'ccp_alpha': 0.01, 'max_depth': 6, 'max_featu...               6
# 71  {'ccp_alpha': 0.01, 'max_depth': 6, 'max_featu...               6
#
#    param_max_samples
# 0                0.4
# 1                0.6
# 2                0.8
# 3                0.4
# 4                0.6
# ..               ...
# 67               0.6
# 68               0.8
# 69               0.4
# 70               0.6
# 71               0.8
#
# [72 rows x 4 columns]

# %%
sns.relplot(x = "param_max_depth", 
            y = "mean_test_neg_mean_squared_error", # error in y axis
            style="param_max_samples", # max number % of rows by tree
            hue="param_ccp_alpha",
            col="param_max_features",
            kind = "line", data=results)

# %%
dep_resoult = model_result.best_estimator_

# %%
y_pred_V1 = dep_resoult.predict(X)
y_pred_V1
# Out:
# array([0.00494512, 0.84344898, 0.55000456, ..., 0.27366092, 0.06600246,
#        0.76022437])

# %%
threshold = 0.5
y_pred_V1_bin = np.where(y_pred_V1 > threshold, 1, 0)
y_pred_V1_bin
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
from sklearn.metrics import confusion_matrix

def confusion(ytest,y_pred):
    names=["No depresive","Depressive"]
    cm=confusion_matrix(y,y_pred_V1_bin)
    f,ax=plt.subplots(figsize=(5,5))
    sns.heatmap(cm,annot=True,linewidth=.5,linecolor="r",fmt=".0f",ax=ax)
    plt.xlabel("y_pred")
    plt.ylabel("y_true")
    ax.set_xticklabels(names)
    ax.set_yticklabels(names)
    plt.show()

    return

# %%
confusion(y,y_pred_V1_bin)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y,y_pred_V1_bin)
# Out:
# 0.9256574271499645

# %% [markdown]
# The cross-validation by 7 had an accuracy of 0.925657, which is slightly better than doing it by 3 but lower than 5.
# - Higher cross-validation doesn't give better results.

# %%
grid_solver.best_estimator_

# %% [markdown]
# # apply the best estimator to Test dataframe

# %%
Mental_1 = pd.read_csv('Datasheet/MH.Clean.Test.1.csv')

# %%
Mental_1.drop(columns=['id'],axis=1)

# %%
modelo_MH = model_result.best_estimator_

# %%
modelo_MH

# %%
y_pre = modelo_MH.predict(Mental_1.drop(columns=['id'],axis=1))

# %%
y_pre

# %%
# define a threshold
threshold = 0.5
y_pre_bin = np.where(y_pre > threshold, 1, 0)

# %%
y_pre_bin

# %%
Mental_1['Depression']= y_pre_bin

# %%
Mental_1

# %%
Mental_1['Depression'].value_counts()

# %%
print(Mental_1.keys())

# %%
sample_submission = Mental_1.drop(columns=['Gender', 'Age', 'Have you ever had suicidal thoughts ?',
       'Work/Study Hours', 'Financial Stress','Family History of Mental Illness', 'Pressure', 'Satisfaction'],axis=1)

# %%
sample_submission

# %%
sample_submission.to_csv('sample_submission_1.csv', index=False)
