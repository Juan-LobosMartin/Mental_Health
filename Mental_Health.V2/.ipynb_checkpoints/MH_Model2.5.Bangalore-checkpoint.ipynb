# %% [markdown]
# # Model for Bangalore

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Mental_Health_Bangalore = pd.read_csv('Datasheet/MH.Bangalore.Clean.2.csv')

# %%
Mental_Health_Bangalore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4123 entries, 0 to 4122
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     4123 non-null   int64
#  1   Gender                                 4123 non-null   int64
#  2   Age                                    4123 non-null   float64
#  3   City                                   4123 non-null   object
#  4   Sleep Duration                         4123 non-null   float64
#  5   Dietary Habits                         4123 non-null   float64
#  6   Have you ever had suicidal thoughts ?  4123 non-null   int64
#  7   Work/Study Hours                       4123 non-null   float64
#  8   Financial Stress                       4123 non-null   float64
#  9   Family History of Mental Illness       4123 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import scale
import sklearn
from sklearn.tree import DecisionTreeClassifier # predict proba
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import scale
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.impute import SimpleImputer
import xgboost as xgb
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier

# %%
model_Bangalore = XGBClassifier()

# %%
model_Bangalore.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
# ...

# %%
params = {'base_score': [0.5],
         'booster': ['gbtree'],
         'colsample_bylevel': [1],
         'colsample_bynode': [0.6],
         'colsample_bytree': [0.7],
         'gamma': [0.01],
         'learning_rate': [0.06,0.05,0.04,0.02],
         'max_depth':[2,3,4],
         'min_child_weight': [1],
         'n_estimators': [400,500,600],
         'n_jobs': [-1],
         'reg_alpha': [0.1],
         'reg_lambda': [0.01,0.1],
         'scale_pos_weight': [1],
         'subsample': [0.9]}

# %%
scoring = ["roc_auc"]
grid_solver = GridSearchCV(estimator = model_Bangalore,
                   param_grid = params,
                   scoring = scoring,
                   cv = 5,
                   n_jobs=-1,
                   refit="roc_auc",
                   verbose = 2)

# %%
X = Mental_Health_Bangalore.drop(columns = ["City","Depression"])
y = Mental_Health_Bangalore["Depression"]
Bangalore_results = grid_solver.fit(X,y)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits

# %%
Bangalore_results.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=0.6, colsample_bytree=0.7,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.01,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.04, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_Bangalore = Bangalore_results.predict(X)
y_pred_Bangalore
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(4123,))

# %%
# define a threshold
# threshold = 0.5
# y_pre_bin = np.where(y_pre > threshold, 1, 0)

# %%
from sklearn.metrics import confusion_matrix

def confusion(ytest,y_pred):
    names=["No depresive","Depressive"]
    cm=confusion_matrix(ytest,y_pred)
    f,ax=plt.subplots(figsize=(5,5))
    sns.heatmap(cm,annot=True,linewidth=.5,linecolor="r",fmt=".0f",ax=ax)
    plt.xlabel("y_pred")
    plt.ylabel("y_true")
    ax.set_xticklabels(names)
    ax.set_yticklabels(names)
    plt.show()

    return

# %%
confusion(y,y_pred_Bangalore)

# %%
from sklearn.metrics import accuracy_score
Xboost_City = accuracy_score(y,y_pred_Bangalore)
Xboost_City
# Out:
# 0.9507640067911715

# %% [markdown]
# ### Model Random Forest

# %%
# X = Mental_Health_Agra.drop(columns = ["City","Depression"])
# y = Mental_Health_Agra["Depression"]

# %%
# check the param of the model 'Random Forest'
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# modification of the param 'Random Forest'
paramsF = {'ccp_alpha': [0.0 ,0.01],
 'max_depth': [3, 4, 5, 6], # branches of the trees
 'max_features': [0.1, 0.3, 0.6], # features considered
 'max_samples': [0.4, 0.6,0.8], # test-train population
 'n_estimators': [1000], # number trees
 'n_jobs': [-1]} # multicore

# %%
n_cv = 5
model_city_F = RandomForestRegressor()

scoring = ['neg_mean_squared_error', 'explained_variance', 'r2']

# I made the evaluation with GridSeacrh
grid_city_Forest = GridSearchCV(estimator = model_city_F, # model to train
                           param_grid = paramsF, # param_grid
                           scoring = scoring,
                           cv = n_cv, #number of independent 
                           refit = 'neg_mean_squared_error',
                           verbose = 2)

# %%
# searchin for the in the forest.
model_City_solver = grid_city_Forest.fit(X, y)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   0.6s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   0.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   0.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   0.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.4, n_estimators=1000, n_jobs=-1; total time=   0.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   0.5s
# [CV] END ccp_alpha=0.0, max_depth=3, max_features=0.1, max_samples=0.6, n_estimators=1000, n_jobs=-1; total time=   0.5s
# ...

# %%
Forest_City = model_City_solver.best_estimator_
Forest_City
# Out:
# RandomForestRegressor(max_depth=6, max_features=0.6, max_samples=0.4,
#                       n_estimators=1000, n_jobs=-1)

# %%
y_pred_F = Forest_City.predict(X)
y_pred_F
# Out:
# array([0.11423022, 0.0084835 , 0.00375284, ..., 0.00993635, 0.04335698,
#        0.00718475], shape=(4123,))

# %%
threshold = 0.5
y_pred_F_bin = np.where(y_pred_F > threshold, 1, 0)
y_pred_F_bin
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(4123,))

# %%
confusion(y,y_pred_F_bin)

# %%
Forest_City = accuracy_score(y,y_pred_F_bin)
Forest_City
# Out:
# 0.9524617996604414

# %%
Xboost_City - Forest_City
# Out:
# -0.001697792869269965

# %% [markdown]
# ## Test Bangalore

# %% [markdown]
# ### In Bangalore, it seems that the best model is Random Forest

# %%
MH_Test_Bangalore = pd.read_csv('Datasheet/MH.Bangalore.Test.Clean.2.csv')
MH_Test_Bangalore.head(3)
# Out:
#        id  Gender   Age       City  Sleep Duration  Dietary Habits  \
# 0  140741       0  46.0  Bangalore             5.5             0.0
# 1  140755       1  48.0  Bangalore             4.5             1.0
# 2  140811       0  30.0  Bangalore             8.5             0.0
#
#    Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                      1               4.0               1.0
# 1                                      1               5.0               2.0
# 2                                      1               6.0               4.0
#
#    Family History of Mental Illness  Work  Satisfaction  Pressure
# 0                                 0     1           2.0       1.0
# 1                                 1     1           2.0       1.0
# 2                                 1     0           4.0       3.0

# %%
Bangalore_model = model_City_solver.best_estimator_

# %%
Prediction_Bangalore = Bangalore_model.predict(MH_Test_Bangalore.drop(columns = ["City"]))

# %%
Prediction_Bangalore
# Out:
# array([0.03016844, 0.03906939, 0.80753058, ..., 0.05346755, 0.05317695,
#        0.01401625], shape=(2707,))

# %%
MH_Test_Bangalore["Depression"]=Prediction_Bangalore

# %%
Submission_Bangalore = MH_Test_Bangalore[['id','Depression']]
Submission_Bangalore

# %%
# df_results = result.sort_values(by='id', ascending=True).reset_index(drop=True)

# %%
Submission_Bangalore.to_csv('Datasheet/Submission.2.Bangalore.csv', index=False)
