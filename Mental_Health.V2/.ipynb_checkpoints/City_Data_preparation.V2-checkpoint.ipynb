# %% [markdown]
# ## Study and preparation of the  Mental health (train)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Mental_Health = pd.read_csv('Datasheet/Mental_Health_train.csv')

# %%
Mental_Health.head(3)
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
#
#   Profession  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0       Chef                NaN            5.0   NaN                 NaN
# 1    Teacher                NaN            4.0   NaN                 NaN
# 2        NaN                5.0            NaN  8.97                 2.0
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0               2.0  More than 8 hours        Healthy      BHM
# 1               3.0  Less than 5 hours      Unhealthy      LLB
# 2               NaN          5-6 hours        Healthy  B.Pharm
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No               1.0               2.0
# 1                                   Yes               7.0               3.0
# 2                                   Yes               3.0               1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           0
# 1                               No           1
# 2                               No           1

# %%
def horas_cat(value):
    if value in ["Less than 5 hours", "3-4 hours", "1-2 hours", "2-3 hours","4-5 hours"]:
        return 4.5
    elif value in ["5-6 hours"]:
        return 5.5
    elif value in ["6-7 hours", "6-8 hours"]:
        return 6.5
    elif value in ["7-8 hours"]:
        return 7.5
    elif value in [ "More than 8 hours"]:
        return 8.5
    elif value in [ "8-9 hours", "9-10 hours", "9-11 hours", "10-11 hours"]:
        return 10
    elif value in [ "50-75 hours", "55-66 hours", "60-65 hours", "20-21 hours", "35-36 hours","40-45 hours",
                   "45-48 hours"]:
        return 12 
    else:
        return np.nan

# %%
Mental_Health['Sleep Duration'] = Mental_Health['Sleep Duration'].apply(horas_cat)

# %%
Mental_Health['Sleep Duration']=Mental_Health['Sleep Duration'].fillna(Mental_Health['Sleep Duration'].mean())

# %%
Mental_Health['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# 4.500000     38809
# 7.500000     36969
# 8.500000     32726
# 5.500000     32142
# 6.448133        32
# 6.500000        12
# 10.000000        6
# 12.000000        4
# Name: count, dtype: int64

# %%
sns.histplot(data=Mental_Health, x='Sleep Duration',binwidth=0.8, hue='Depression', kde=True)
plt.title(f'sleep')
plt.show()

# %%
sns.histplot(data=Mental_Health, x='Sleep Duration', binwidth=0.8, hue='Depression', kde=True)
plt.ylim(bottom=0, top=100 )  # Set the minimum y-axis value to 0 (optional)
plt.title(f'Sleep')
plt.show()

# %%
    def Comida(value):
        if value in ['Healthy', "More Healthy"]:
            return 2
        elif value in ['Unhealthy']:
            return 0
        elif value in ['Moderate']:
            return 1
        else:
            return np.nan# Modules

# %%
Mental_Health['Dietary Habits'] = Mental_Health['Dietary Habits'].apply(Comida)

# %%
Mental_Health['Dietary Habits']=Mental_Health['Dietary Habits'].fillna(Mental_Health['Dietary Habits'].mean())

# %%
Mental_Health['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# 1.000000    49705
# 0.000000    46227
# 2.000000    44743
# 0.989451       25
# Name: count, dtype: int64

# %%
sns.histplot(data=Mental_Health, x='Dietary Habits',binwidth=0.5, hue='Depression', kde=True)
plt.title(f'Dietary Habits')
plt.show()

# %%
Mental_Health = Mental_Health.drop(columns = ['Name', 'Profession', 'CGPA', 'Degree'])

# %%
Mental_Health.head(3)
# Out:
#    id  Gender   Age           City Working Professional or Student  \
# 0   0  Female  49.0       Ludhiana            Working Professional
# 1   1    Male  26.0       Varanasi            Working Professional
# 2   2    Male  33.0  Visakhapatnam                         Student
#
#    Academic Pressure  Work Pressure  Study Satisfaction  Job Satisfaction  \
# 0                NaN            5.0                 NaN               2.0
# 1                NaN            4.0                 NaN               3.0
# 2                5.0            NaN                 2.0               NaN
#
#    Sleep Duration  Dietary Habits Have you ever had suicidal thoughts ?  \
# 0             8.5             2.0                                    No
# 1             4.5             0.0                                   Yes
# 2             5.5             2.0                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               1.0               2.0                               No
# 1               7.0               3.0                               No
# 2               3.0               1.0                               No
#
#    Depression
# 0           0
# 1           1
# 2           1

# %%
Mental_Health['Work'] = Mental_Health['Working Professional or Student'] #change the name of the column
Mental_Health.drop(columns='Working Professional or Student',axis=1, inplace=True) 
Mental_Health.head(3)
# Out:
#    id  Gender   Age           City  Academic Pressure  Work Pressure  \
# 0   0  Female  49.0       Ludhiana                NaN            5.0
# 1   1    Male  26.0       Varanasi                NaN            4.0
# 2   2    Male  33.0  Visakhapatnam                5.0            NaN
#
#    Study Satisfaction  Job Satisfaction  Sleep Duration  Dietary Habits  \
# 0                 NaN               2.0             8.5             2.0
# 1                 NaN               3.0             4.5             0.0
# 2                 2.0               NaN             5.5             2.0
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No               1.0               2.0
# 1                                   Yes               7.0               3.0
# 2                                   Yes               3.0               1.0
#
#   Family History of Mental Illness  Depression                  Work
# 0                               No           0  Working Professional
# 1                               No           1  Working Professional
# 2                               No           1               Student

# %%
#drop 'Nan' to make the new columns
Mental_Health['Academic Pressure'] = Mental_Health['Academic Pressure'].replace(to_replace=np.nan, value=0)
Mental_Health['Work Pressure'] = Mental_Health['Work Pressure'].replace(to_replace=np.nan, value=0)
Mental_Health['Study Satisfaction'] = Mental_Health['Study Satisfaction'].replace(to_replace=np.nan, value=0)
Mental_Health['Job Satisfaction'] = Mental_Health['Job Satisfaction'].replace(to_replace=np.nan, value=0)
# Female = 1, Male = 0 
Mental_Health['Gender'] = Mental_Health['Gender'].replace(to_replace={'Female': 1, 'Male': 0})
#Yes = 1, No = 0
Mental_Health['Have you ever had suicidal thoughts ?'] = Mental_Health['Have you ever had suicidal thoughts ?'].replace(to_replace={'Yes': 1, 'No': 0})
Mental_Health['Family History of Mental Illness'] = Mental_Health['Family History of Mental Illness'].replace(to_replace={'Yes': 1, 'No': 0})
#Worker=1 Student = 0
Mental_Health['Work'] = Mental_Health['Work'].replace(to_replace={'Working Professional': 1, 'Student': 0})
Mental_Health.tail(3)
# Out:
# /var/folders/jr/mmqlfvl506g3k7f00dtr8kg00000gp/T/ipykernel_37914/3657639919.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Mental_Health['Gender'] = Mental_Health['Gender'].replace(to_replace={'Female': 1, 'Male': 0})
# /var/folders/jr/mmqlfvl506g3k7f00dtr8kg00000gp/T/ipykernel_37914/3657639919.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Mental_Health['Have you ever had suicidal thoughts ?'] = Mental_Health['Have you ever had suicidal thoughts ?'].replace(to_replace={'Yes': 1, 'No': 0})
# /var/folders/jr/mmqlfvl506g3k7f00dtr8kg00000gp/T/ipykernel_37914/3657639919.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Mental_Health['Family History of Mental Illness'] = Mental_Health['Family History of Mental Illness'].replace(to_replace={'Yes': 1, 'No': 0})
# /var/folders/jr/mmqlfvl506g3k7f00dtr8kg00000gp/T/ipykernel_37914/3657639919.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Mental_Health['Work'] = Mental_Health['Work'].replace(to_replace={'Working Professional': 1, 'Student': 0})
#             id  Gender   Age      City  Academic Pressure  Work Pressure  \
# 140697  140697       1  24.0   Kolkata                0.0            3.0
# 140698  140698       1  49.0  Srinagar                0.0            5.0
# 140699  140699       0  27.0     Patna                4.0            0.0
#
#         Study Satisfaction  Job Satisfaction  Sleep Duration  Dietary Habits  \
# 140697                 0.0               1.0             8.5             1.0
# 140698                 0.0               2.0             5.5             1.0
# 140699                 1.0               0.0             4.5             2.0
#
#         Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 140697                                      0               4.0
# 140698                                      1              10.0
# 140699                                      1               2.0
#
#         Financial Stress  Family History of Mental Illness  Depression  Work
# 140697               4.0                                 0           0     1
# 140698               1.0                                 0           0     1
# 140699               3.0                                 1           1     0

# %%
Mental_Health['Satisfaction'] = Mental_Health['Study Satisfaction']+ Mental_Health['Job Satisfaction']

# %%
Mental_Health['Satisfaction'].replace(to_replace=[6 , 7], value=5,inplace=True)
# Out:
# /var/folders/jr/mmqlfvl506g3k7f00dtr8kg00000gp/T/ipykernel_37914/2163809441.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Mental_Health['Satisfaction'].replace(to_replace=[6 , 7], value=5,inplace=True)

# %%
Mental_Health = Mental_Health.drop(columns=['Study Satisfaction', 'Job Satisfaction'],axis=1)
Mental_Health['Pressure'] = Mental_Health['Academic Pressure']+ Mental_Health['Work Pressure']
Mental_Health.head(3)
# Out:
#    id  Gender   Age           City  Academic Pressure  Work Pressure  \
# 0   0       1  49.0       Ludhiana                0.0            5.0
# 1   1       0  26.0       Varanasi                0.0            4.0
# 2   2       0  33.0  Visakhapatnam                5.0            0.0
#
#    Sleep Duration  Dietary Habits  Have you ever had suicidal thoughts ?  \
# 0             8.5             2.0                                      0
# 1             4.5             0.0                                      1
# 2             5.5             2.0                                      1
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0               1.0               2.0                                 0
# 1               7.0               3.0                                 0
# 2               3.0               1.0                                 0
#
#    Depression  Work  Satisfaction  Pressure
# 0           0     1           2.0       5.0
# 1           1     1           3.0       4.0
# 2           1     0           2.0       5.0

# %%
Mental_Health['Depresion'] = Mental_Health['Depression']
Mental_Health.head(3)
# Out:
#    id  Gender   Age           City  Academic Pressure  Work Pressure  \
# 0   0       1  49.0       Ludhiana                0.0            5.0
# 1   1       0  26.0       Varanasi                0.0            4.0
# 2   2       0  33.0  Visakhapatnam                5.0            0.0
#
#    Sleep Duration  Dietary Habits  Have you ever had suicidal thoughts ?  \
# 0             8.5             2.0                                      0
# 1             4.5             0.0                                      1
# 2             5.5             2.0                                      1
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0               1.0               2.0                                 0
# 1               7.0               3.0                                 0
# 2               3.0               1.0                                 0
#
#    Depression  Work  Satisfaction  Pressure  Depresion
# 0           0     1           2.0       5.0          0
# 1           1     1           3.0       4.0          1
# 2           1     0           2.0       5.0          1

# %%
Mental_Health = Mental_Health.drop(columns=['Depression'],axis=1)

# %%
Mental_Health = Mental_Health.drop(columns=['Work Pressure', 'Academic Pressure'],axis=1)

# %%
corr = Mental_Health.corr(numeric_only=True)
cmap = sns.diverging_palette(-1, 1, s=100, l=50, n=15, center="dark", as_cmap=True)
plt.figure(figsize=(9, 6))
sns.heatmap(Mental_Health.corr(numeric_only=True), annot=True, fmt='.2f', linewidth=0.5, cmap='coolwarm', mask=np.triu(Mental_Health.corr(numeric_only=True)))
plt.show()

# %%
Mental_Health['Depression'] = Mental_Health['Depresion']

# %%
Mental_Health = Mental_Health.drop(columns=['Depresion'],axis=1)

# %%
Mental_Health
# Out:
#             id  Gender   Age           City  Sleep Duration  Dietary Habits  \
# 0            0       1  49.0       Ludhiana             8.5             2.0
# 1            1       0  26.0       Varanasi             4.5             0.0
# 2            2       0  33.0  Visakhapatnam             5.5             2.0
# 3            3       0  22.0         Mumbai             4.5             1.0
# 4            4       1  30.0         Kanpur             5.5             0.0
# ...        ...     ...   ...            ...             ...             ...
# 140695  140695       1  18.0      Ahmedabad             5.5             0.0
# 140696  140696       1  41.0      Hyderabad             7.5             1.0
# 140697  140697       1  24.0        Kolkata             8.5             1.0
# 140698  140698       1  49.0       Srinagar             5.5             1.0
# 140699  140699       0  27.0          Patna             4.5             2.0
#
#         Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                           0               1.0
# 1                                           1               7.0
# 2                                           1               3.0
# 3                                           1              10.0
# 4                                           1               9.0
# ...                                       ...               ...
# 140695                                      0               2.0
# 140696                                      1               6.0
# 140697                                      0               4.0
# 140698                                      1              10.0
# 140699                                      1               2.0
#
#         Financial Stress  Family History of Mental Illness  Work  \
# 0                    2.0                                 0     1
# 1                    3.0                                 0     1
# 2                    1.0                                 0     0
# 3                    1.0                                 1     1
# 4                    4.0                                 1     1
# ...                  ...                               ...   ...
# 140695               4.0                                 1     1
# 140696               5.0                                 1     1
# 140697               4.0                                 0     1
# 140698               1.0                                 0     1
# 140699               3.0                                 1     0
#
#         Satisfaction  Pressure  Depression
# 0                2.0       5.0           0
# 1                3.0       4.0           1
# 2                2.0       5.0           1
# 3                1.0       5.0           1
# 4                1.0       1.0           0
# ...              ...       ...         ...
# 140695           4.0       5.0           1
# 140696           4.0       5.0           0
# 140697           1.0       3.0           0
# 140698           2.0       5.0           0
# 140699           1.0       4.0           1
#
# [140700 rows x 14 columns]

# %%
Mental_Health.to_csv('Datasheet/MH.wCity.Clean.2.csv', index=False)
